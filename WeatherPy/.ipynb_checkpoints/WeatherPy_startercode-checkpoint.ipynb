# %% [markdown]
# WeatherPy

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
#output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 634

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#build base url and query url

base_url = "http://api.openweathermap.org/data/2.5/weather?"

query_url = base_url+f"appid={weather_api_key}&q=city"

#print(base_url)

#print(query_url)

# %%
#lists to hold data from api requests

name = []
city_cloudiness = []
city_country = []
city_date = []
city_humidity = []
city_lat = []
city_long = []
city_maxtemp = []
city_windspeed = []

# set counters
count = 1
group_counter = 1

print(f" --- Beginning Data Retrieval --- ")


for city in cities:

   
    query_url = base_url+f"appid={weather_api_key}&q={city}"
    city_data_response = requests.get(query_url)
    city_data = city_data_response.json()
    
    
    
    try:
         
        name.append(city_data["name"])
        city_cloudiness.append(city_data["clouds"]["all"])
        city_country.append(city_data["sys"]["country"])
        city_date.append(city_data["dt"])
        city_humidity.append(city_data["main"]["humidity"])
        city_lat.append(city_data["coord"]["lat"])
        city_long.append(city_data["coord"]["lon"])
        city_maxtemp.append(city_data["main"]["temp_max"])
        city_windspeed.append(city_data["wind"]["speed"])

        
        print(f"Processing record {count} of set {group_counter} | {city}")

        count += 1 

   # if count > 50:
        # starting new group
        #group_counter += 1
        #count = 1

        # pausing script to comply with API limits
       # time.sleep(10)
      
     
    except:
        print(f"City not found, skipping...")
        pass
   
    
    if count > 50:
        count = 1
        group_counter += 1
        
        
print(f" --- Data Retrieval Complete --- ")
# Out:
#  --- Beginning Data Retrieval ---
# City not found, skipping...
# Processing record 1 of set 1 | meulaboh
# Processing record 2 of set 1 | namibe
# Processing record 3 of set 1 | kununurra
# City not found, skipping...
# Processing record 4 of set 1 | vodnyy
# Processing record 5 of set 1 | hilo
# Processing record 6 of set 1 | rikitea
# Processing record 7 of set 1 | port alfred
# Processing record 8 of set 1 | ushuaia
# Processing record 9 of set 1 | sitka
# Processing record 10 of set 1 | mataura
# Processing record 11 of set 1 | alofi
# Processing record 12 of set 1 | athabasca
# Processing record 13 of set 1 | znamenskoye
# Processing record 14 of set 1 | awbari
# Processing record 15 of set 1 | hermanus
# Processing record 16 of set 1 | hammerfest
# Processing record 17 of set 1 | bulembu
# Processing record 18 of set 1 | santa teresa
# Processing record 19 of set 1 | ostrovnoy
# Processing record 20 of set 1 | punta arenas
# Processing record 21 of set 1 | busselton
# Processing record 22 of set 1 | zhigansk
# Processing record 23 of set 1 | tuktoyaktuk
# Processing record 24 of set 1 | vaini
# Processing record 25 of set 1 | port hardy
# Processing record 26 of set 1 | khatanga
# Processing record 27 of set 1 | biltine
# Processing record 28 of set 1 | usvyaty
# Processing record 29 of set 1 | christchurch
# Processing record 30 of set 1 | carnarvon
# Processing record 31 of set 1 | lashio
# Processing record 32 of set 1 | yar-sale
# Processing record 33 of set 1 | araouane
# Processing record 34 of set 1 | atuona
# City not found, skipping...
# Processing record 35 of set 1 | bredasdorp
# City not found, skipping...
# Processing record 36 of set 1 | arraial do cabo
# Processing record 37 of set 1 | roma
# Processing record 38 of set 1 | chuy
# Processing record 39 of set 1 | narrabri
# Processing record 40 of set 1 | westport
# Processing record 41 of set 1 | abalak
# Processing record 42 of set 1 | barrow
# Processing record 43 of set 1 | pisco
# Processing record 44 of set 1 | zyryanka
# City not found, skipping...
# Processing record 45 of set 1 | dorado
# Processing record 46 of set 1 | bethel
# City not found, skipping...
# Processing record 47 of set 1 | castro
# Processing record 48 of set 1 | new norfolk
# Processing record 49 of set 1 | lais
# Processing record 50 of set 1 | howard springs
# Processing record 1 of set 2 | deputatskiy
# Processing record 2 of set 2 | bowen
# Processing record 3 of set 2 | bluff
# Processing record 4 of set 2 | codrington
# Processing record 5 of set 2 | hambantota
# Processing record 6 of set 2 | lasa
# Processing record 7 of set 2 | samana
# Processing record 8 of set 2 | paamiut
# Processing record 9 of set 2 | grindavik
# Processing record 10 of set 2 | butaritari
# Processing record 11 of set 2 | saint-philippe
# Processing record 12 of set 2 | san quintin
# Processing record 13 of set 2 | parola
# Processing record 14 of set 2 | chokurdakh
# Processing record 15 of set 2 | gharghoda
# Processing record 16 of set 2 | conde
# City not found, skipping...
# Processing record 17 of set 2 | shimoda
# Processing record 18 of set 2 | georgetown
# Processing record 19 of set 2 | tolmachevo
# Processing record 20 of set 2 | vila franca do campo
# Processing record 21 of set 2 | kieta
# Processing record 22 of set 2 | dongsheng
# Processing record 23 of set 2 | inirida
# Processing record 24 of set 2 | hobart
# Processing record 25 of set 2 | maltahohe
# Processing record 26 of set 2 | ukiah
# Processing record 27 of set 2 | aranos
# Processing record 28 of set 2 | tadine
# Processing record 29 of set 2 | cape town
# Processing record 30 of set 2 | thompson
# Processing record 31 of set 2 | norrtalje
# Processing record 32 of set 2 | taruma
# Processing record 33 of set 2 | dingle
# Processing record 34 of set 2 | lanzhou
# City not found, skipping...
# Processing record 35 of set 2 | nikolskoye
# Processing record 36 of set 2 | soller
# Processing record 37 of set 2 | denpasar
# Processing record 38 of set 2 | albany
# Processing record 39 of set 2 | mehamn
# Processing record 40 of set 2 | airai
# Processing record 41 of set 2 | sao filipe
# Processing record 42 of set 2 | balaipungut
# Processing record 43 of set 2 | constitucion
# Processing record 44 of set 2 | mar del plata
# Processing record 45 of set 2 | iqaluit
# City not found, skipping...
# Processing record 46 of set 2 | viransehir
# Processing record 47 of set 2 | port elizabeth
# Processing record 48 of set 2 | pangnirtung
# Processing record 49 of set 2 | khuzhir
# Processing record 50 of set 2 | kapaa
# Processing record 1 of set 3 | tigil
# Processing record 2 of set 3 | matara
# Processing record 3 of set 3 | rockland
# Processing record 4 of set 3 | rabo de peixe
# Processing record 5 of set 3 | klaksvik
# Processing record 6 of set 3 | vasylivka
# Processing record 7 of set 3 | poso
# Processing record 8 of set 3 | kismayo
# Processing record 9 of set 3 | fort nelson
# Processing record 10 of set 3 | provideniya
# Processing record 11 of set 3 | puerto ayora
# Processing record 12 of set 3 | qaanaaq
# Processing record 13 of set 3 | calamar
# Processing record 14 of set 3 | avarua
# Processing record 15 of set 3 | montepuez
# Processing record 16 of set 3 | okhotsk
# Processing record 17 of set 3 | conceicao da barra
# Processing record 18 of set 3 | gat
# Processing record 19 of set 3 | jamestown
# Processing record 20 of set 3 | cairns
# Processing record 21 of set 3 | qui nhon
# Processing record 22 of set 3 | zabid
# Processing record 23 of set 3 | grand gaube
# City not found, skipping...
# Processing record 24 of set 3 | oktyabrskiy
# Processing record 25 of set 3 | biak
# Processing record 26 of set 3 | mayo
# Processing record 27 of set 3 | ponta do sol
# Processing record 28 of set 3 | abha
# Processing record 29 of set 3 | ancud
# Processing record 30 of set 3 | cobija
# Processing record 31 of set 3 | ilovlya
# Processing record 32 of set 3 | sargatskoye
# City not found, skipping...
# Processing record 33 of set 3 | victoria
# Processing record 34 of set 3 | iskateley
# Processing record 35 of set 3 | severo-kurilsk
# Processing record 36 of set 3 | tasiilaq
# Processing record 37 of set 3 | tiksi
# Processing record 38 of set 3 | hamada
# Processing record 39 of set 3 | lavrentiya
# Processing record 40 of set 3 | mahebourg
# Processing record 41 of set 3 | kungurtug
# Processing record 42 of set 3 | natalio
# Processing record 43 of set 3 | maslovare
# Processing record 44 of set 3 | yellowknife
# Processing record 45 of set 3 | cayenne
# Processing record 46 of set 3 | lebu
# Processing record 47 of set 3 | lantawan
# Processing record 48 of set 3 | san patricio
# Processing record 49 of set 3 | kambove
# Processing record 50 of set 3 | tres arroyos
# Processing record 1 of set 4 | kamenka
# Processing record 2 of set 4 | nola
# Processing record 3 of set 4 | iquitos
# Processing record 4 of set 4 | czestochowa
# Processing record 5 of set 4 | domoni
# Processing record 6 of set 4 | bol
# Processing record 7 of set 4 | rognan
# City not found, skipping...
# Processing record 8 of set 4 | cidreira
# Processing record 9 of set 4 | podosinovets
# Processing record 10 of set 4 | ocos
# Processing record 11 of set 4 | pathein
# Processing record 12 of set 4 | tanabe
# Processing record 13 of set 4 | hovd
# City not found, skipping...
# Processing record 14 of set 4 | launceston
# Processing record 15 of set 4 | luganville
# Processing record 16 of set 4 | raudeberg
# Processing record 17 of set 4 | baykit
# Processing record 18 of set 4 | mallaig
# Processing record 19 of set 4 | hermiston
# Processing record 20 of set 4 | abilene
# Processing record 21 of set 4 | fortuna
# Processing record 22 of set 4 | kloulklubed
# Processing record 23 of set 4 | yankton
# Processing record 24 of set 4 | bambous virieux
# Processing record 25 of set 4 | balabac
# Processing record 26 of set 4 | hithadhoo
# Processing record 27 of set 4 | mezen
# Processing record 28 of set 4 | cabo san lucas
# Processing record 29 of set 4 | farafangana
# Processing record 30 of set 4 | egvekinot
# Processing record 31 of set 4 | ilulissat
# Processing record 32 of set 4 | lodja
# Processing record 33 of set 4 | rodrigues alves
# Processing record 34 of set 4 | camana
# Processing record 35 of set 4 | gobabis
# Processing record 36 of set 4 | hualmay
# Processing record 37 of set 4 | la ronge
# Processing record 38 of set 4 | kahului
# Processing record 39 of set 4 | tromso
# Processing record 40 of set 4 | kaitangata
# Processing record 41 of set 4 | adrar
# Processing record 42 of set 4 | kudahuvadhoo
# Processing record 43 of set 4 | zhezkazgan
# Processing record 44 of set 4 | ribeira grande
# Processing record 45 of set 4 | lengshuijiang
# Processing record 46 of set 4 | hay river
# Processing record 47 of set 4 | guerrero negro
# Processing record 48 of set 4 | pacific grove
# Processing record 49 of set 4 | krosno odrzanskie
# Processing record 50 of set 4 | saint-augustin
# Processing record 1 of set 5 | dharchula
# Processing record 2 of set 5 | rundu
# City not found, skipping...
# Processing record 3 of set 5 | muros
# Processing record 4 of set 5 | kez
# Processing record 5 of set 5 | longyearbyen
# Processing record 6 of set 5 | laguna
# Processing record 7 of set 5 | itapirapua
# City not found, skipping...
# City not found, skipping...
# Processing record 8 of set 5 | tual
# Processing record 9 of set 5 | kalabo
# Processing record 10 of set 5 | monroe
# Processing record 11 of set 5 | pitimbu
# Processing record 12 of set 5 | pipar
# Processing record 13 of set 5 | polson
# Processing record 14 of set 5 | tarakan
# Processing record 15 of set 5 | tilichiki
# Processing record 16 of set 5 | maniitsoq
# Processing record 17 of set 5 | upernavik
# Processing record 18 of set 5 | malkangiri
# Processing record 19 of set 5 | talnakh
# Processing record 20 of set 5 | batagay-alyta
# Processing record 21 of set 5 | ginir
# Processing record 22 of set 5 | geraldton
# Processing record 23 of set 5 | koceljeva
# Processing record 24 of set 5 | touros
# Processing record 25 of set 5 | kingaroy
# Processing record 26 of set 5 | urucara
# Processing record 27 of set 5 | doha
# City not found, skipping...
# City not found, skipping...
# City not found, skipping...
# Processing record 28 of set 5 | ibra
# Processing record 29 of set 5 | yulara
# Processing record 30 of set 5 | east london
# City not found, skipping...
# Processing record 31 of set 5 | nemuro
# Processing record 32 of set 5 | henties bay
# Processing record 33 of set 5 | warrenton
# City not found, skipping...
# Processing record 34 of set 5 | lapua
# Processing record 35 of set 5 | amli
# Processing record 36 of set 5 | berlevag
# Processing record 37 of set 5 | kysyl-syr
# City not found, skipping...
# Processing record 38 of set 5 | akyab
# Processing record 39 of set 5 | esperance
# Processing record 40 of set 5 | polyarnyy
# Processing record 41 of set 5 | hirara
# Processing record 42 of set 5 | honiara
# Processing record 43 of set 5 | simao dias
# Processing record 44 of set 5 | umm kaddadah
# Processing record 45 of set 5 | havelock
# City not found, skipping...
# Processing record 46 of set 5 | vryburg
# Processing record 47 of set 5 | anadyr
# Processing record 48 of set 5 | bengkulu
# Processing record 49 of set 5 | indore
# Processing record 50 of set 5 | misratah
# City not found, skipping...
# Processing record 1 of set 6 | rawson
# Processing record 2 of set 6 | kondrovo
# Processing record 3 of set 6 | khandyga
# Processing record 4 of set 6 | saint-pierre
# Processing record 5 of set 6 | charagua
# Processing record 6 of set 6 | buenaventura
# Processing record 7 of set 6 | itoman
# Processing record 8 of set 6 | cukai
# Processing record 9 of set 6 | skjervoy
# Processing record 10 of set 6 | cockburn town
# Processing record 11 of set 6 | pemba
# Processing record 12 of set 6 | lorengau
# City not found, skipping...
# Processing record 13 of set 6 | cherskiy
# Processing record 14 of set 6 | babushkin
# Processing record 15 of set 6 | nanortalik
# Processing record 16 of set 6 | saskylakh
# Processing record 17 of set 6 | lima
# Processing record 18 of set 6 | sola
# Processing record 19 of set 6 | okha
# Processing record 20 of set 6 | yershichi
# Processing record 21 of set 6 | fairbanks
# Processing record 22 of set 6 | college
# Processing record 23 of set 6 | sao paulo de olivenca
# Processing record 24 of set 6 | san policarpo
# Processing record 25 of set 6 | bukama
# Processing record 26 of set 6 | contamana
# Processing record 27 of set 6 | naravarikuppam
# Processing record 28 of set 6 | husavik
# Processing record 29 of set 6 | hami
# Processing record 30 of set 6 | kodiak
# Processing record 31 of set 6 | flinders
# Processing record 32 of set 6 | tuatapere
# Processing record 33 of set 6 | upington
# Processing record 34 of set 6 | beyneu
# City not found, skipping...
# Processing record 35 of set 6 | bulawayo
# Processing record 36 of set 6 | okakarara
# City not found, skipping...
# Processing record 37 of set 6 | guisa
# Processing record 38 of set 6 | narsaq
# Processing record 39 of set 6 | mayumba
# City not found, skipping...
# Processing record 40 of set 6 | chateaubelair
# Processing record 41 of set 6 | regeneracao
# Processing record 42 of set 6 | beaufort
# Processing record 43 of set 6 | katherine
# City not found, skipping...
# Processing record 44 of set 6 | barranca
# Processing record 45 of set 6 | mount isa
# Processing record 46 of set 6 | champerico
# Processing record 47 of set 6 | bonavista
# Processing record 48 of set 6 | yeppoon
# Processing record 49 of set 6 | alekseyevsk
# Processing record 50 of set 6 | ati
# Processing record 1 of set 7 | biograd na moru
# City not found, skipping...
# Processing record 2 of set 7 | faanui
# Processing record 3 of set 7 | praia da vitoria
# Processing record 4 of set 7 | sao joao da barra
# Processing record 5 of set 7 | dharampuri
# Processing record 6 of set 7 | avera
# Processing record 7 of set 7 | corralillo
# Processing record 8 of set 7 | opuwo
# Processing record 9 of set 7 | clevelandia
# Processing record 10 of set 7 | taoudenni
# Processing record 11 of set 7 | sertania
# Processing record 12 of set 7 | sorland
# City not found, skipping...
# Processing record 13 of set 7 | portland
# Processing record 14 of set 7 | hasaki
# Processing record 15 of set 7 | margate
# Processing record 16 of set 7 | katsuura
# Processing record 17 of set 7 | gold coast
# Processing record 18 of set 7 | mwinilunga
# Processing record 19 of set 7 | torbay
# City not found, skipping...
# Processing record 20 of set 7 | riosucio
# Processing record 21 of set 7 | andenes
# Processing record 22 of set 7 | klyuchi
# Processing record 23 of set 7 | nouadhibou
# Processing record 24 of set 7 | san cristobal
# Processing record 25 of set 7 | padilla
# Processing record 26 of set 7 | myre
# Processing record 27 of set 7 | half moon bay
# Processing record 28 of set 7 | shizunai
# Processing record 29 of set 7 | rock hill
# Processing record 30 of set 7 | solnechnyy
# Processing record 31 of set 7 | moussoro
# Processing record 32 of set 7 | thunder bay
# Processing record 33 of set 7 | nara
# Processing record 34 of set 7 | wukari
# Processing record 35 of set 7 | sakaraha
# Processing record 36 of set 7 | semey
# Processing record 37 of set 7 | isangel
# Processing record 38 of set 7 | hutchinson
# Processing record 39 of set 7 | bushehr
# Processing record 40 of set 7 | lander
# Processing record 41 of set 7 | pirawa
# Processing record 42 of set 7 | korla
# Processing record 43 of set 7 | tawang
# Processing record 44 of set 7 | chapais
# Processing record 45 of set 7 | saldanha
# Processing record 46 of set 7 | nuuk
# Processing record 47 of set 7 | livingston
# Processing record 48 of set 7 | olonets
# Processing record 49 of set 7 | ballina
# Processing record 50 of set 7 | samarai
# Processing record 1 of set 8 | fort smith
# City not found, skipping...
# Processing record 2 of set 8 | bonham
# Processing record 3 of set 8 | togur
# Processing record 4 of set 8 | broome
# Processing record 5 of set 8 | filingue
# Processing record 6 of set 8 | vra
# City not found, skipping...
# Processing record 7 of set 8 | juneau
# Processing record 8 of set 8 | naze
# Processing record 9 of set 8 | great yarmouth
# Processing record 10 of set 8 | ozernovskiy
# Processing record 11 of set 8 | harboore
# Processing record 12 of set 8 | davenda
# Processing record 13 of set 8 | liberal
# Processing record 14 of set 8 | novikovo
# Processing record 15 of set 8 | altay
# City not found, skipping...
# Processing record 16 of set 8 | kavieng
# Processing record 17 of set 8 | nome
# Processing record 18 of set 8 | aracruz
# Processing record 19 of set 8 | hanzhong
# Processing record 20 of set 8 | saint george
# Processing record 21 of set 8 | rocha
# City not found, skipping...
# Processing record 22 of set 8 | abu samrah
# Processing record 23 of set 8 | beloha
# Processing record 24 of set 8 | kailua
# Processing record 25 of set 8 | antofagasta
# Processing record 26 of set 8 | muzhi
# Processing record 27 of set 8 | the valley
# Processing record 28 of set 8 | stornoway
# Processing record 29 of set 8 | harper
# Processing record 30 of set 8 | bacungan
# Processing record 31 of set 8 | chicama
# Processing record 32 of set 8 | vardo
# Processing record 33 of set 8 | sisimiut
# Processing record 34 of set 8 | sinnamary
# Processing record 35 of set 8 | kuching
# Processing record 36 of set 8 | japura
# Processing record 37 of set 8 | souillac
# Processing record 38 of set 8 | sompeta
# Processing record 39 of set 8 | caceres
# Processing record 40 of set 8 | pevek
# Processing record 41 of set 8 | nelson bay
# Processing record 42 of set 8 | clyde river
# Processing record 43 of set 8 | at-bashi
# Processing record 44 of set 8 | grants
# Processing record 45 of set 8 | west bay
# Processing record 46 of set 8 | aswan
# Processing record 47 of set 8 | lompoc
# Processing record 48 of set 8 | natal
# Processing record 49 of set 8 | alice springs
# Processing record 50 of set 8 | aklavik
# Processing record 1 of set 9 | houma
# Processing record 2 of set 9 | caravelas
# Processing record 3 of set 9 | paciran
# Processing record 4 of set 9 | kumertau
# Processing record 5 of set 9 | payo
# Processing record 6 of set 9 | dolores
# Processing record 7 of set 9 | dohar
# Processing record 8 of set 9 | karacsond
# Processing record 9 of set 9 | vao
# Processing record 10 of set 9 | sambava
# City not found, skipping...
# City not found, skipping...
# Processing record 11 of set 9 | axim
# Processing record 12 of set 9 | kuvshinovo
# Processing record 13 of set 9 | vostok
# Processing record 14 of set 9 | wagga wagga
# Processing record 15 of set 9 | mukhen
# Processing record 16 of set 9 | trojan
# Processing record 17 of set 9 | arlit
# Processing record 18 of set 9 | pakxan
# Processing record 19 of set 9 | sekoma
# Processing record 20 of set 9 | port blair
# Processing record 21 of set 9 | harrison
# Processing record 22 of set 9 | sciacca
# Processing record 23 of set 9 | ambilobe
# Processing record 24 of set 9 | jackson
# Processing record 25 of set 9 | komsomolskiy
# Processing record 26 of set 9 | hobyo
# Processing record 27 of set 9 | ayagoz
# Processing record 28 of set 9 | bam
# Processing record 29 of set 9 | bequimao
# Processing record 30 of set 9 | bathsheba
# Processing record 31 of set 9 | kavaratti
# Processing record 32 of set 9 | karlstad
# Processing record 33 of set 9 | huallanca
# Processing record 34 of set 9 | mto wa mbu
# Processing record 35 of set 9 | gazojak
# Processing record 36 of set 9 | rio gallegos
# Processing record 37 of set 9 | tautira
# Processing record 38 of set 9 | port augusta
# Processing record 39 of set 9 | kodinsk
# City not found, skipping...
# Processing record 40 of set 9 | mitsamiouli
# Processing record 41 of set 9 | itanagar
# Processing record 42 of set 9 | lampa
# Processing record 43 of set 9 | dunedin
# Processing record 44 of set 9 | santa isabel do rio negro
# Processing record 45 of set 9 | feldkirchen an der donau
# Processing record 46 of set 9 | sibolga
# Processing record 47 of set 9 | teseney
# Processing record 48 of set 9 | dicabisagan
# Processing record 49 of set 9 | ketchikan
# Processing record 50 of set 9 | paita
# Processing record 1 of set 10 | tura
# Processing record 2 of set 10 | tezu
# Processing record 3 of set 10 | hervey bay
# Processing record 4 of set 10 | ihosy
# Processing record 5 of set 10 | sebeta
# Processing record 6 of set 10 | sur
# Processing record 7 of set 10 | predivinsk
# Processing record 8 of set 10 | auki
# Processing record 9 of set 10 | huinan
# Processing record 10 of set 10 | honningsvag
# Processing record 11 of set 10 | dikson
# Processing record 12 of set 10 | turriff
# Processing record 13 of set 10 | storforshei
# Processing record 14 of set 10 | yambio
# Processing record 15 of set 10 | chumikan
# Processing record 16 of set 10 | iranshahr
# City not found, skipping...
# City not found, skipping...
# Processing record 17 of set 10 | guymon
# Processing record 18 of set 10 | concepcion del oro
# Processing record 19 of set 10 | krasnyy oktyabr
# City not found, skipping...
# Processing record 20 of set 10 | norman wells
# Processing record 21 of set 10 | baracoa
# Processing record 22 of set 10 | mali
# Processing record 23 of set 10 | juegang
# Processing record 24 of set 10 | porto novo
# City not found, skipping...
# Processing record 25 of set 10 | ormara
# Processing record 26 of set 10 | camapua
# Processing record 27 of set 10 | sabha
# Processing record 28 of set 10 | xingyi
# Processing record 29 of set 10 | svarstad
# Processing record 30 of set 10 | los llanos de aridane
# Processing record 31 of set 10 | moron
# Processing record 32 of set 10 | talakan
# Processing record 33 of set 10 | lityn
# Processing record 34 of set 10 | faya
# Processing record 35 of set 10 | jiuquan
# Processing record 36 of set 10 | lata
# Processing record 37 of set 10 | san pedro
# City not found, skipping...
# City not found, skipping...
# Processing record 38 of set 10 | siilinjarvi
# Processing record 39 of set 10 | garden city
# Processing record 40 of set 10 | puqi
# Processing record 41 of set 10 | kruisfontein
# Processing record 42 of set 10 | qaqortoq
# Processing record 43 of set 10 | atasu
# Processing record 44 of set 10 | santa cruz
# Processing record 45 of set 10 | bandundu
# Processing record 46 of set 10 | rio grande
# Processing record 47 of set 10 | otavi
# Processing record 48 of set 10 | baruun-urt
# Processing record 49 of set 10 | berbera
# City not found, skipping...
# Processing record 50 of set 10 | jiangkou
# Processing record 1 of set 11 | gunjur
# Processing record 2 of set 11 | port macquarie
# Processing record 3 of set 11 | nisia floresta
# Processing record 4 of set 11 | pringsewu
# Processing record 5 of set 11 | muhos
# Processing record 6 of set 11 | taltal
# Processing record 7 of set 11 | atar
# Processing record 8 of set 11 | mount gambier
# Processing record 9 of set 11 | cuiluan
# Processing record 10 of set 11 | saint-joseph
# Processing record 11 of set 11 | port hedland
# Processing record 12 of set 11 | big rapids
# Processing record 13 of set 11 | kiama
# Processing record 14 of set 11 | ferrol
# Processing record 15 of set 11 | tiznit
# Processing record 16 of set 11 | rantepao
# Processing record 17 of set 11 | riyadh
# Processing record 18 of set 11 | pombas
# Processing record 19 of set 11 | poole
# Processing record 20 of set 11 | san felipe
# Processing record 21 of set 11 | mae ramat
# Processing record 22 of set 11 | kirovskiy
# Processing record 23 of set 11 | bonthe
# Processing record 24 of set 11 | derzhavinsk
# Processing record 25 of set 11 | cine
# Processing record 26 of set 11 | zhangye
# City not found, skipping...
# Processing record 27 of set 11 | la rioja
# Processing record 28 of set 11 | drexel heights
# Processing record 29 of set 11 | bataipora
# Processing record 30 of set 11 | beringovskiy
# Processing record 31 of set 11 | saint-felicien
# Processing record 32 of set 11 | ileza
# Processing record 33 of set 11 | jinxiang
# Processing record 34 of set 11 | goderich
# Processing record 35 of set 11 | carberry
# City not found, skipping...
# City not found, skipping...
# Processing record 36 of set 11 | svetlaya
# Processing record 37 of set 11 | kuusamo
# Processing record 38 of set 11 | gigmoto
# Processing record 39 of set 11 | soyo
# Processing record 40 of set 11 | acapulco
# Processing record 41 of set 11 | cafelandia
# Processing record 42 of set 11 | jaypur
# Processing record 43 of set 11 | shieli
# Processing record 44 of set 11 | artyom
# Processing record 45 of set 11 | oktyabrskoye
# Processing record 46 of set 11 | novyy svit
# Processing record 47 of set 11 | sao francisco de paula
# Processing record 48 of set 11 | chernyshevskiy
# Processing record 49 of set 11 | kutum
# Processing record 50 of set 11 | porterville
# Processing record 1 of set 12 | leningradskiy
# Processing record 2 of set 12 | curup
# City not found, skipping...
# Processing record 3 of set 12 | yenagoa
# Processing record 4 of set 12 | prince albert
# City not found, skipping...
# Processing record 5 of set 12 | manjacaze
# Processing record 6 of set 12 | bedong
# Processing record 7 of set 12 | linkou
# City not found, skipping...
# Processing record 8 of set 12 | radomsko
# City not found, skipping...
# Processing record 9 of set 12 | ugoofaaru
# Processing record 10 of set 12 | ahipara
# Processing record 11 of set 12 | igarka
# Processing record 12 of set 12 | josanicka banja
# Processing record 13 of set 12 | abasolo
# Processing record 14 of set 12 | gurmatkal
# Processing record 15 of set 12 | altamirano
# Processing record 16 of set 12 | batsfjord
# Processing record 17 of set 12 | sao jose da coroa grande
# Processing record 18 of set 12 | haines junction
# Processing record 19 of set 12 | hojai
# Processing record 20 of set 12 | bubaque
# Processing record 21 of set 12 | mocuba
# Processing record 22 of set 12 | novopokrovka
# Processing record 23 of set 12 | defiance
# Processing record 24 of set 12 | novopavlovka
# Processing record 25 of set 12 | petropavlovsk-kamchatskiy
# Processing record 26 of set 12 | liku
# Processing record 27 of set 12 | ternate
# Processing record 28 of set 12 | xam nua
# Processing record 29 of set 12 | bud
# Processing record 30 of set 12 | necochea
# Processing record 31 of set 12 | petropavlovka
#  --- Data Retrieval Complete ---

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_data_df = {
    "City": name,
    "Country": city_country,
    "Lat": city_lat,
    "Lng": city_long,
    "Max Temp": city_maxtemp,
    "Humidity": city_humidity,
    "Cloudiness": city_cloudiness,
    "Wind Speed":city_windspeed,
    "Date": city_date
            }




city_data_df = pd.DataFrame(city_data_df)
city_data_df.head()
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Meulaboh      ID   4.1363   96.1285    297.83        87          79
# 1  Mossamedes      AO -15.1961   12.1522    300.19        73          48
# 2   Kununurra      AU -15.7667  128.7333    291.15        94          54
# 3      Vodnyy      RU  63.5046   53.4095    275.81        92          88
# 4        Hilo      US  19.7297 -155.0900    300.15        54          40
#
#    Wind Speed        Date
# 0        1.02  1618441028
# 1        0.58  1618440772
# 2        0.92  1618441028
# 3        3.23  1618441029
# 4        5.66  1618440805

# %%
# city_data_df.tocsv("../output_data/city_data.csv")

city_data_df.to_csv(r'city_data.csv', index=False, header=True)

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
city_data_df.loc[city_data_df["Humidity"] >100]["City"].count()
# Out:
# 0

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
