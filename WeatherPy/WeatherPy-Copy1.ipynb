# %% [markdown]
# WeatherPy

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
#output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 594

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#build base url and query url

base_url = "http://api.openweathermap.org/data/2.5/weather?"

query_url = base_url+f"appid={weather_api_key}&q=city"

#print(base_url)

#print(query_url)

# %%
#lists to hold data from api requests

name = []
city_cloudiness = []
city_country = []
city_date = []
city_humidity = []
city_lat = []
city_long = []
city_maxtemp = []
city_windspeed = []

# set counters
count = 1
group_counter = 1

print(f" --- Beginning Data Retrieval --- ")

for city in cities:

   
    query_url = base_url+f"units=imperial&appid={weather_api_key}&q={city}"
    city_data_response = requests.get(query_url)
    city_data = city_data_response.json()
    
        
    try:
         
        name.append(city_data["name"])
        city_cloudiness.append(city_data["clouds"]["all"])
        city_country.append(city_data["sys"]["country"])
        city_date.append(city_data["dt"])
        city_humidity.append(city_data["main"]["humidity"])
        city_lat.append(city_data["coord"]["lat"])
        city_long.append(city_data["coord"]["lon"])
        city_maxtemp.append(city_data["main"]["temp_max"])
        city_windspeed.append(city_data["wind"]["speed"])

        
        print(f"Processing record {count} of set {group_counter} | {city}")

        count += 1 
     
    except:
        print(f"City not found, skipping...")
        pass
   
    
    if count > 50:
        count = 1
        group_counter += 1
        
        
print(f" --- Data Retrieval Complete --- ")
# Out:
#  --- Beginning Data Retrieval ---
# Processing record 1 of set 1 | ancud
# Processing record 2 of set 1 | komsomolskiy
# Processing record 3 of set 1 | arraial do cabo
# Processing record 4 of set 1 | hilo
# Processing record 5 of set 1 | cheyenne
# Processing record 6 of set 1 | hirara
# Processing record 7 of set 1 | san quintin
# Processing record 8 of set 1 | nikolskoye
# City not found, skipping...
# Processing record 9 of set 1 | zhigansk
# City not found, skipping...
# Processing record 10 of set 1 | tasiilaq
# Processing record 11 of set 1 | pouebo
# Processing record 12 of set 1 | saint george
# Processing record 13 of set 1 | rikitea
# Processing record 14 of set 1 | vaini
# Processing record 15 of set 1 | bluff
# Processing record 16 of set 1 | dikson
# City not found, skipping...
# Processing record 17 of set 1 | lexington park
# Processing record 18 of set 1 | albany
# Processing record 19 of set 1 | ushuaia
# Processing record 20 of set 1 | kapaa
# Processing record 21 of set 1 | kalmunai
# City not found, skipping...
# Processing record 22 of set 1 | maniitsoq
# Processing record 23 of set 1 | puerto ayora
# Processing record 24 of set 1 | jamestown
# Processing record 25 of set 1 | punta arenas
# Processing record 26 of set 1 | tatawin
# Processing record 27 of set 1 | hobart
# Processing record 28 of set 1 | vestmannaeyjar
# City not found, skipping...
# Processing record 29 of set 1 | kavieng
# Processing record 30 of set 1 | dalvik
# Processing record 31 of set 1 | klaksvik
# Processing record 32 of set 1 | vila franca do campo
# Processing record 33 of set 1 | monrovia
# Processing record 34 of set 1 | hambantota
# City not found, skipping...
# Processing record 35 of set 1 | hamilton
# Processing record 36 of set 1 | bilma
# Processing record 37 of set 1 | niteroi
# Processing record 38 of set 1 | port alfred
# Processing record 39 of set 1 | bethel
# Processing record 40 of set 1 | homer
# Processing record 41 of set 1 | alofi
# Processing record 42 of set 1 | hilton head island
# City not found, skipping...
# Processing record 43 of set 1 | mehamn
# Processing record 44 of set 1 | aban
# Processing record 45 of set 1 | olden
# City not found, skipping...
# Processing record 46 of set 1 | grindavik
# Processing record 47 of set 1 | great yarmouth
# Processing record 48 of set 1 | geraldton
# Processing record 49 of set 1 | busselton
# Processing record 50 of set 1 | lelystad
# Processing record 1 of set 2 | henties bay
# Processing record 2 of set 2 | kaitangata
# City not found, skipping...
# Processing record 3 of set 2 | mount gambier
# Processing record 4 of set 2 | ilulissat
# Processing record 5 of set 2 | avarua
# Processing record 6 of set 2 | tougan
# Processing record 7 of set 2 | boende
# Processing record 8 of set 2 | roald
# Processing record 9 of set 2 | cabo san lucas
# Processing record 10 of set 2 | mecca
# Processing record 11 of set 2 | vanimo
# Processing record 12 of set 2 | rocha
# Processing record 13 of set 2 | barrow
# Processing record 14 of set 2 | yulara
# Processing record 15 of set 2 | chihuahua
# Processing record 16 of set 2 | kralendijk
# Processing record 17 of set 2 | mar del plata
# Processing record 18 of set 2 | mahebourg
# Processing record 19 of set 2 | mataura
# Processing record 20 of set 2 | znamenskoye
# Processing record 21 of set 2 | pevek
# Processing record 22 of set 2 | vagur
# Processing record 23 of set 2 | longyearbyen
# Processing record 24 of set 2 | tuktoyaktuk
# Processing record 25 of set 2 | cabinda
# City not found, skipping...
# Processing record 26 of set 2 | smoky lake
# Processing record 27 of set 2 | ribeira grande
# Processing record 28 of set 2 | leningradskiy
# Processing record 29 of set 2 | luanda
# Processing record 30 of set 2 | hermanus
# Processing record 31 of set 2 | poya
# Processing record 32 of set 2 | ahipara
# Processing record 33 of set 2 | marawi
# Processing record 34 of set 2 | khatanga
# Processing record 35 of set 2 | chokurdakh
# Processing record 36 of set 2 | zaysan
# Processing record 37 of set 2 | guerrero negro
# Processing record 38 of set 2 | kavaratti
# Processing record 39 of set 2 | upernavik
# Processing record 40 of set 2 | butaritari
# Processing record 41 of set 2 | aswan
# Processing record 42 of set 2 | atuona
# Processing record 43 of set 2 | port elizabeth
# Processing record 44 of set 2 | la seyne-sur-mer
# Processing record 45 of set 2 | gat
# Processing record 46 of set 2 | lebu
# Processing record 47 of set 2 | constitucion
# Processing record 48 of set 2 | severo-kurilsk
# Processing record 49 of set 2 | lydenburg
# Processing record 50 of set 2 | talnakh
# Processing record 1 of set 3 | saskylakh
# Processing record 2 of set 3 | lagoa
# Processing record 3 of set 3 | sao joao da barra
# Processing record 4 of set 3 | vardo
# Processing record 5 of set 3 | sambava
# Processing record 6 of set 3 | yelovo
# Processing record 7 of set 3 | srednekolymsk
# Processing record 8 of set 3 | oriximina
# Processing record 9 of set 3 | port lincoln
# Processing record 10 of set 3 | aksarayskiy
# Processing record 11 of set 3 | yellowknife
# Processing record 12 of set 3 | la massana
# Processing record 13 of set 3 | saint-augustin
# Processing record 14 of set 3 | campbell river
# Processing record 15 of set 3 | mana
# Processing record 16 of set 3 | ballina
# Processing record 17 of set 3 | luena
# Processing record 18 of set 3 | san cristobal
# Processing record 19 of set 3 | emerald
# Processing record 20 of set 3 | nador
# Processing record 21 of set 3 | laksham
# Processing record 22 of set 3 | padang
# Processing record 23 of set 3 | quang ngai
# Processing record 24 of set 3 | yarmouth
# Processing record 25 of set 3 | nanlong
# Processing record 26 of set 3 | hami
# Processing record 27 of set 3 | san joaquin
# Processing record 28 of set 3 | ust-nera
# Processing record 29 of set 3 | kruisfontein
# City not found, skipping...
# Processing record 30 of set 3 | airai
# Processing record 31 of set 3 | namtsy
# Processing record 32 of set 3 | nanortalik
# Processing record 33 of set 3 | bredasdorp
# Processing record 34 of set 3 | katsuura
# Processing record 35 of set 3 | banjar
# Processing record 36 of set 3 | torbay
# Processing record 37 of set 3 | bengkulu
# Processing record 38 of set 3 | yumen
# City not found, skipping...
# Processing record 39 of set 3 | edgewater
# Processing record 40 of set 3 | namibe
# Processing record 41 of set 3 | moron
# Processing record 42 of set 3 | fairbanks
# Processing record 43 of set 3 | tautira
# Processing record 44 of set 3 | matagami
# Processing record 45 of set 3 | jasper
# Processing record 46 of set 3 | qaanaaq
# Processing record 47 of set 3 | nelson bay
# Processing record 48 of set 3 | marzuq
# Processing record 49 of set 3 | vaitape
# Processing record 50 of set 3 | peniche
# Processing record 1 of set 4 | paidha
# Processing record 2 of set 4 | shirokiy
# Processing record 3 of set 4 | codrington
# Processing record 4 of set 4 | chumikan
# Processing record 5 of set 4 | mitsamiouli
# City not found, skipping...
# Processing record 6 of set 4 | sarakhs
# Processing record 7 of set 4 | kaka
# Processing record 8 of set 4 | san juan bautista
# Processing record 9 of set 4 | lompoc
# Processing record 10 of set 4 | koumac
# Processing record 11 of set 4 | cape town
# Processing record 12 of set 4 | xining
# Processing record 13 of set 4 | clyde river
# Processing record 14 of set 4 | warrington
# City not found, skipping...
# Processing record 15 of set 4 | kodiak
# Processing record 16 of set 4 | kawalu
# Processing record 17 of set 4 | castro
# Processing record 18 of set 4 | bakchar
# Processing record 19 of set 4 | nishihara
# Processing record 20 of set 4 | saint-francois
# Processing record 21 of set 4 | namatanai
# City not found, skipping...
# Processing record 22 of set 4 | gashua
# Processing record 23 of set 4 | korla
# Processing record 24 of set 4 | provideniya
# City not found, skipping...
# Processing record 25 of set 4 | coffeyville
# Processing record 26 of set 4 | bydgoszcz
# City not found, skipping...
# Processing record 27 of set 4 | ust-kuyga
# Processing record 28 of set 4 | rudbar
# Processing record 29 of set 4 | hobyo
# Processing record 30 of set 4 | goderich
# Processing record 31 of set 4 | ponta do sol
# Processing record 32 of set 4 | victoria
# Processing record 33 of set 4 | tezu
# Processing record 34 of set 4 | georgetown
# Processing record 35 of set 4 | alta floresta
# Processing record 36 of set 4 | husavik
# Processing record 37 of set 4 | half moon bay
# Processing record 38 of set 4 | zyryanka
# Processing record 39 of set 4 | kyzyl-suu
# Processing record 40 of set 4 | norman wells
# Processing record 41 of set 4 | bartica
# Processing record 42 of set 4 | beringovskiy
# Processing record 43 of set 4 | college
# Processing record 44 of set 4 | pangnirtung
# Processing record 45 of set 4 | ostrovnoy
# Processing record 46 of set 4 | port-gentil
# Processing record 47 of set 4 | ligayan
# Processing record 48 of set 4 | zigong
# Processing record 49 of set 4 | thompson
# Processing record 50 of set 4 | narsaq
# Processing record 1 of set 5 | adre
# Processing record 2 of set 5 | pullman
# Processing record 3 of set 5 | ariquemes
# City not found, skipping...
# Processing record 4 of set 5 | saint-philippe
# Processing record 5 of set 5 | preobrazheniye
# City not found, skipping...
# Processing record 6 of set 5 | kilembe
# Processing record 7 of set 5 | cockburn town
# Processing record 8 of set 5 | grand gaube
# Processing record 9 of set 5 | pollachi
# Processing record 10 of set 5 | faya
# Processing record 11 of set 5 | maralal
# Processing record 12 of set 5 | labuhan
# Processing record 13 of set 5 | gazojak
# Processing record 14 of set 5 | novo aripuana
# Processing record 15 of set 5 | boden
# Processing record 16 of set 5 | evensk
# Processing record 17 of set 5 | wewak
# Processing record 18 of set 5 | mbumi
# Processing record 19 of set 5 | tazovskiy
# Processing record 20 of set 5 | iqaluit
# Processing record 21 of set 5 | cherskiy
# Processing record 22 of set 5 | ketchikan
# Processing record 23 of set 5 | valle hermoso
# Processing record 24 of set 5 | sal rei
# Processing record 25 of set 5 | faanui
# Processing record 26 of set 5 | yakeshi
# Processing record 27 of set 5 | pozo colorado
# Processing record 28 of set 5 | lavrentiya
# Processing record 29 of set 5 | hithadhoo
# Processing record 30 of set 5 | santa rosalia
# Processing record 31 of set 5 | belyy yar
# Processing record 32 of set 5 | kahului
# Processing record 33 of set 5 | camacha
# City not found, skipping...
# Processing record 34 of set 5 | pokhara
# Processing record 35 of set 5 | charters towers
# Processing record 36 of set 5 | luderitz
# Processing record 37 of set 5 | sayyan
# Processing record 38 of set 5 | new norfolk
# Processing record 39 of set 5 | wanlaweyn
# Processing record 40 of set 5 | barao de melgaco
# Processing record 41 of set 5 | raudeberg
# Processing record 42 of set 5 | hoa binh
# Processing record 43 of set 5 | buala
# Processing record 44 of set 5 | koshurnikovo
# Processing record 45 of set 5 | ouegoa
# City not found, skipping...
# Processing record 46 of set 5 | iquitos
# City not found, skipping...
# Processing record 47 of set 5 | mareeba
# Processing record 48 of set 5 | tolon
# Processing record 49 of set 5 | zeya
# Processing record 50 of set 5 | skelleftea
# Processing record 1 of set 6 | puerto cabezas
# Processing record 2 of set 6 | wawa
# Processing record 3 of set 6 | malakal
# Processing record 4 of set 6 | vitim
# Processing record 5 of set 6 | tessalit
# Processing record 6 of set 6 | bayan
# Processing record 7 of set 6 | aktau
# Processing record 8 of set 6 | manacapuru
# Processing record 9 of set 6 | kaeo
# City not found, skipping...
# Processing record 10 of set 6 | dahuk
# City not found, skipping...
# Processing record 11 of set 6 | east london
# Processing record 12 of set 6 | shihezi
# Processing record 13 of set 6 | carnarvon
# Processing record 14 of set 6 | amahai
# Processing record 15 of set 6 | hasaki
# Processing record 16 of set 6 | shelburne
# Processing record 17 of set 6 | bodmin
# Processing record 18 of set 6 | churapcha
# Processing record 19 of set 6 | bundaberg
# Processing record 20 of set 6 | de aar
# Processing record 21 of set 6 | swan river
# Processing record 22 of set 6 | ca mau
# Processing record 23 of set 6 | baie-comeau
# Processing record 24 of set 6 | muleba
# Processing record 25 of set 6 | paita
# Processing record 26 of set 6 | lata
# Processing record 27 of set 6 | payo
# Processing record 28 of set 6 | mount isa
# Processing record 29 of set 6 | diamantino
# Processing record 30 of set 6 | san patricio
# Processing record 31 of set 6 | quisqueya
# Processing record 32 of set 6 | havre-saint-pierre
# City not found, skipping...
# Processing record 33 of set 6 | alterosa
# Processing record 34 of set 6 | kutum
# City not found, skipping...
# Processing record 35 of set 6 | oranjemund
# Processing record 36 of set 6 | penzance
# Processing record 37 of set 6 | donja dubica
# Processing record 38 of set 6 | erzin
# Processing record 39 of set 6 | waipawa
# Processing record 40 of set 6 | mastic beach
# Processing record 41 of set 6 | esperance
# Processing record 42 of set 6 | marsh harbour
# Processing record 43 of set 6 | yelizovo
# Processing record 44 of set 6 | olafsvik
# Processing record 45 of set 6 | goldsboro
# Processing record 46 of set 6 | strezhevoy
# Processing record 47 of set 6 | nouadhibou
# Processing record 48 of set 6 | chantada
# Processing record 49 of set 6 | aklavik
# Processing record 50 of set 6 | tuatapere
# Processing record 1 of set 7 | cedar city
# Processing record 2 of set 7 | dunedin
# Processing record 3 of set 7 | westport
# Processing record 4 of set 7 | the valley
# Processing record 5 of set 7 | beloha
# Processing record 6 of set 7 | srandakan
# Processing record 7 of set 7 | olavarria
# Processing record 8 of set 7 | cidreira
# Processing record 9 of set 7 | fukue
# Processing record 10 of set 7 | arica
# City not found, skipping...
# Processing record 11 of set 7 | dondo
# Processing record 12 of set 7 | segezha
# Processing record 13 of set 7 | asau
# Processing record 14 of set 7 | bonthe
# City not found, skipping...
# Processing record 15 of set 7 | maunabo
# Processing record 16 of set 7 | nyurba
# Processing record 17 of set 7 | chuzhou
# Processing record 18 of set 7 | cayenne
# Processing record 19 of set 7 | hueytamalco
# Processing record 20 of set 7 | tayu
# City not found, skipping...
# Processing record 21 of set 7 | bairiki
# Processing record 22 of set 7 | qaqortoq
# Processing record 23 of set 7 | portland
# Processing record 24 of set 7 | carmen
# Processing record 25 of set 7 | de panne
# Processing record 26 of set 7 | olinda
# Processing record 27 of set 7 | danesti
# Processing record 28 of set 7 | santa cruz
# Processing record 29 of set 7 | marystown
# Processing record 30 of set 7 | veraval
# Processing record 31 of set 7 | los llanos de aridane
# Processing record 32 of set 7 | arman
# Processing record 33 of set 7 | verkhnyaya inta
# Processing record 34 of set 7 | yarim
# Processing record 35 of set 7 | lundazi
# Processing record 36 of set 7 | noumea
# Processing record 37 of set 7 | laguna
# Processing record 38 of set 7 | sao miguel do araguaia
# Processing record 39 of set 7 | waingapu
# Processing record 40 of set 7 | petropavlovka
# City not found, skipping...
# Processing record 41 of set 7 | suhbaatar
# Processing record 42 of set 7 | harnosand
# Processing record 43 of set 7 | sao filipe
# Processing record 44 of set 7 | jiwani
# Processing record 45 of set 7 | omboue
# Processing record 46 of set 7 | evora
# Processing record 47 of set 7 | espanola
# Processing record 48 of set 7 | gorazde
# Processing record 49 of set 7 | kholodnyy
# Processing record 50 of set 7 | senneterre
# City not found, skipping...
# Processing record 1 of set 8 | fortuna
# Processing record 2 of set 8 | bodden town
# Processing record 3 of set 8 | kulhudhuffushi
# Processing record 4 of set 8 | champerico
# Processing record 5 of set 8 | spring hill
# Processing record 6 of set 8 | mezen
# City not found, skipping...
# Processing record 7 of set 8 | dingle
# City not found, skipping...
# Processing record 8 of set 8 | tiksi
# Processing record 9 of set 8 | kozhevnikovo
# Processing record 10 of set 8 | atambua
# Processing record 11 of set 8 | krasnogorskiy
# Processing record 12 of set 8 | eten
# Processing record 13 of set 8 | pimentel
# City not found, skipping...
# Processing record 14 of set 8 | necochea
# Processing record 15 of set 8 | glace bay
# Processing record 16 of set 8 | flin flon
# Processing record 17 of set 8 | monaragala
# Processing record 18 of set 8 | mafinga
# Processing record 19 of set 8 | lucea
# Processing record 20 of set 8 | kaseda
# Processing record 21 of set 8 | burnie
# Processing record 22 of set 8 | alice springs
# Processing record 23 of set 8 | hofn
# Processing record 24 of set 8 | santa rosa
# Processing record 25 of set 8 | chuy
# Processing record 26 of set 8 | muzhi
# Processing record 27 of set 8 | uchiza
# Processing record 28 of set 8 | okhotsk
# Processing record 29 of set 8 | ulladulla
# Processing record 30 of set 8 | kailua
# Processing record 31 of set 8 | paso de los toros
# City not found, skipping...
# Processing record 32 of set 8 | gusau
# Processing record 33 of set 8 | gilbues
# Processing record 34 of set 8 | puerto madryn
# Processing record 35 of set 8 | barcelos
# Processing record 36 of set 8 | nemuro
# City not found, skipping...
# Processing record 37 of set 8 | dauphin
# Processing record 38 of set 8 | pizarro
# Processing record 39 of set 8 | duluth
# Processing record 40 of set 8 | souillac
# Processing record 41 of set 8 | pangai
# City not found, skipping...
# Processing record 42 of set 8 | rio gallegos
# Processing record 43 of set 8 | ayan
# City not found, skipping...
# Processing record 44 of set 8 | harper
# Processing record 45 of set 8 | mizan teferi
# Processing record 46 of set 8 | dzhebariki-khaya
# Processing record 47 of set 8 | grand-santi
# Processing record 48 of set 8 | khandagayty
# Processing record 49 of set 8 | coahuayana
# Processing record 50 of set 8 | barra do garcas
# Processing record 1 of set 9 | yar-sale
# Processing record 2 of set 9 | tecoanapa
# Processing record 3 of set 9 | kirando
# Processing record 4 of set 9 | samarai
# Processing record 5 of set 9 | fort nelson
# Processing record 6 of set 9 | tuy hoa
# Processing record 7 of set 9 | katangli
# Processing record 8 of set 9 | lenger
# Processing record 9 of set 9 | mahajanga
# City not found, skipping...
# Processing record 10 of set 9 | tananger
# Processing record 11 of set 9 | rolla
# Processing record 12 of set 9 | mangrol
# Processing record 13 of set 9 | tagusao
# Processing record 14 of set 9 | havoysund
# Processing record 15 of set 9 | otane
# Processing record 16 of set 9 | yenagoa
# Processing record 17 of set 9 | kununurra
# Processing record 18 of set 9 | prudentopolis
# Processing record 19 of set 9 | zhangjiakou
# Processing record 20 of set 9 | bathsheba
# Processing record 21 of set 9 | zhengjiatun
# Processing record 22 of set 9 | oksfjord
# Processing record 23 of set 9 | plouzane
# Processing record 24 of set 9 | purna
# Processing record 25 of set 9 | coquimbo
# City not found, skipping...
# Processing record 26 of set 9 | le port
# Processing record 27 of set 9 | zabol
# Processing record 28 of set 9 | baijiantan
# Processing record 29 of set 9 | ust-ilimsk
# Processing record 30 of set 9 | umm lajj
# City not found, skipping...
# Processing record 31 of set 9 | humaita
# Processing record 32 of set 9 | port macquarie
# Processing record 33 of set 9 | ahualulco
# Processing record 34 of set 9 | drugovo
# Processing record 35 of set 9 | tanout
# City not found, skipping...
# Processing record 36 of set 9 | puerto colombia
# Processing record 37 of set 9 | pozarevac
# Processing record 38 of set 9 | matara
# Processing record 39 of set 9 | daru
# Processing record 40 of set 9 | methoni
# Processing record 41 of set 9 | milas
# Processing record 42 of set 9 | vao
# Processing record 43 of set 9 | leshan
# Processing record 44 of set 9 | cestas
# Processing record 45 of set 9 | sao gabriel da cachoeira
# Processing record 46 of set 9 | denpasar
# Processing record 47 of set 9 | broome
# Processing record 48 of set 9 | zaria
# Processing record 49 of set 9 | lowestoft
# City not found, skipping...
# Processing record 50 of set 9 | sioux lookout
# Processing record 1 of set 10 | taoudenni
# Processing record 2 of set 10 | cheremisinovo
# Processing record 3 of set 10 | uyskoye
# Processing record 4 of set 10 | boali
# Processing record 5 of set 10 | yaan
# Processing record 6 of set 10 | isiro
# City not found, skipping...
# Processing record 7 of set 10 | kayerkan
# Processing record 8 of set 10 | uglovskoye
# Processing record 9 of set 10 | vavozh
# Processing record 10 of set 10 | saint-joseph
# Processing record 11 of set 10 | manokwari
# Processing record 12 of set 10 | mocuba
# Processing record 13 of set 10 | bolgatanga
# Processing record 14 of set 10 | sur
# Processing record 15 of set 10 | puri
# Processing record 16 of set 10 | algiers
# Processing record 17 of set 10 | calvinia
# Processing record 18 of set 10 | hengyang
# Processing record 19 of set 10 | ossora
# Processing record 20 of set 10 | denizli
# Processing record 21 of set 10 | nhulunbuy
# Processing record 22 of set 10 | dezful
# Processing record 23 of set 10 | tilichiki
# Processing record 24 of set 10 | natal
# Processing record 25 of set 10 | xuchang
# Processing record 26 of set 10 | batetskiy
# Processing record 27 of set 10 | bahar
# Processing record 28 of set 10 | awbari
# Processing record 29 of set 10 | siocon
# City not found, skipping...
# Processing record 30 of set 10 | pampa
# Processing record 31 of set 10 | gouyave
# Processing record 32 of set 10 | san roque
# Processing record 33 of set 10 | ayorou
# Processing record 34 of set 10 | flinders
# Processing record 35 of set 10 | taybad
# Processing record 36 of set 10 | kristiansund
# City not found, skipping...
# Processing record 37 of set 10 | mingaora
# Processing record 38 of set 10 | romitan
# Processing record 39 of set 10 | kopavogur
# Processing record 40 of set 10 | terney
# Processing record 41 of set 10 | soavinandriana
# Processing record 42 of set 10 | newtownards
# Processing record 43 of set 10 | alyangula
# Processing record 44 of set 10 | isangel
# Processing record 45 of set 10 | kargasok
# City not found, skipping...
# Processing record 46 of set 10 | najran
# Processing record 47 of set 10 | shingu
# Processing record 48 of set 10 | general roca
# Processing record 49 of set 10 | arkhangelsk
# Processing record 50 of set 10 | sunndalsora
# Processing record 1 of set 11 | hualmay
# Processing record 2 of set 11 | cajetina
# Processing record 3 of set 11 | bousso
# Processing record 4 of set 11 | igarka
# Processing record 5 of set 11 | stonewall
# Processing record 6 of set 11 | qui nhon
# Processing record 7 of set 11 | karaton
# Processing record 8 of set 11 | dandong
# Processing record 9 of set 11 | kolosovka
# Processing record 10 of set 11 | caltanissetta
# Processing record 11 of set 11 | urdoma
# Processing record 12 of set 11 | vodnyy
# Processing record 13 of set 11 | gladstone
# Processing record 14 of set 11 | salalah
# Processing record 15 of set 11 | yavoriv
# Processing record 16 of set 11 | lota
# Processing record 17 of set 11 | winnemucca
# Processing record 18 of set 11 | nicoya
# Processing record 19 of set 11 | bubaque
# Processing record 20 of set 11 | makakilo city
# Processing record 21 of set 11 | doha
# Processing record 22 of set 11 | safford
# Processing record 23 of set 11 | thomaston
# Processing record 24 of set 11 | chitral
# Processing record 25 of set 11 | oskemen
# Processing record 26 of set 11 | marang
# Processing record 27 of set 11 | port hedland
# Processing record 28 of set 11 | millau
# Processing record 29 of set 11 | ambatondrazaka
# Processing record 30 of set 11 | palmer
# Processing record 31 of set 11 | jutai
# Processing record 32 of set 11 | ambon
# Processing record 33 of set 11 | vila velha
# Processing record 34 of set 11 | mirnyy
# Processing record 35 of set 11 | biak
# Processing record 36 of set 11 | buluang
# Processing record 37 of set 11 | krasnoyarskaya
# Processing record 38 of set 11 | koumra
# Processing record 39 of set 11 | kolobrzeg
# Processing record 40 of set 11 | pitimbu
# Processing record 41 of set 11 | chicama
# Processing record 42 of set 11 | arrifes
# Processing record 43 of set 11 | muros
# Processing record 44 of set 11 | kodinar
# City not found, skipping...
# Processing record 45 of set 11 | prince rupert
# Processing record 46 of set 11 | male
# Processing record 47 of set 11 | katiola
# Processing record 48 of set 11 | ust-kulom
#  --- Data Retrieval Complete ---

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_data_df = {
    "City": name,
    "Country": city_country,
    "Lat": city_lat,
    "Lng": city_long,
    "Max Temp": city_maxtemp,
    "Humidity": city_humidity,
    "Cloudiness": city_cloudiness,
    "Wind Speed":city_windspeed,
    "Date": city_date
            }

city_data_df = pd.DataFrame(city_data_df)
city_data_df.head()
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            Ancud      CL -41.8697  -73.8203     51.01       100          90
# 1  Yangi Marg`ilon      UZ  40.4272   71.7189     53.60        76         100
# 2  Arraial do Cabo      BR -22.9661  -42.0278     69.80        83          40
# 3             Hilo      US  19.7297 -155.0900     80.60        57          20
# 4         Cheyenne      US  41.1400 -104.8203     26.60        93          90
#
#    Wind Speed        Date
# 0        3.44  1618445435
# 1        4.00  1618445435
# 2        2.30  1618445436
# 3       12.66  1618445782
# 4       13.80  1618445637

# %%
#city_data_df.to_csv(r'city_data.csv', index=False, header=True)

# %%
city_data_df = pd.read_csv("../city_data.csv")
city_data_df = pd.DataFrame(city_data_df)
city_data_df.head()
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            Ancud      CL -41.8697  -73.8203     51.01       100          90
# 1  Yangi Marg`ilon      UZ  40.4272   71.7189     53.60        76         100
# 2  Arraial do Cabo      BR -22.9661  -42.0278     69.80        83          40
# 3             Hilo      US  19.7297 -155.0900     80.60        57          20
# 4         Cheyenne      US  41.1400 -104.8203     26.60        93          90
#
#    Wind Speed        Date
# 0        3.44  1618445435
# 1        4.00  1618445435
# 2        2.30  1618445436
# 3       12.66  1618445782
# 4       13.80  1618445637

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
city_data_df.loc[city_data_df["Humidity"] >100]["City"].count()
# Out:
# 0

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
x_values = city_lat
y_values = city_maxtemp

plt.title("City Latitudes vs their Max Temperatures")
plt.xlabel("Latitude")
plt.ylabel("Max Temp (F)")
plt.grid()
plt.scatter(x_values, y_values, marker= "o", edgecolor="black")
plt.savefig("../Images/latvstemp.png")
plt.show()

print(f"This figure plots the latitudes of all 596 cities against their respective max temperatures.")
print(f"The data points reflect a curve that reaches its peak (i.e. max temps) close to the equator (latitude of 0).")
# Out:
# This figure plots the latitudes of all 596 cities against their respective max temperatures.
# The data points reflect a curve that reaches its peak (i.e. max temps) close to the equator (latitude of 0).

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
x_values = city_lat
y_values = city_humidity

plt.title("City Latitudes vs their Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity %")
plt.grid()
plt.scatter(x_values, y_values, marker= "o", edgecolor="black")
plt.savefig("../Images/latvshumidity.png")
plt.show()

print(f"Humidity % among the cities seems to be concentrated in the range of 60-100%.")
print(f"The cities in this range are distributed somewhat evenly between -60 and 80 degrees latitude.")
# Out:
# Humidity % among the cities seems to be concentrated in the range of 60-100%.
# The cities in this range are distributed somewhat evenly between -60 and 80 degrees latitude.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
x_values = city_lat
y_values = city_cloudiness

plt.title("City Latitudes vs their Cloudiness %")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness %")
plt.grid()
plt.scatter(x_values, y_values, marker= "o", edgecolor="black")
plt.savefig("../Images/latvsclouds.png")
plt.show()

print(f"Cloudiness % is scattered somewhat evenly from 0 - 100% however there appears to be clusters of cities on both extremes.")
print(f"Latitude does not appear to have any correlation with a cities cloudiness.")
# Out:
# Cloudiness % is scattered somewhat evenly from 0 - 100% however there appears to be clusters of cities on both extremes.
# Latitude does not appear to have any correlation with a cities cloudiness.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
x_values = city_lat
y_values = city_windspeed

plt.title("City Latitudes vs their Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid()
plt.scatter(x_values, y_values, marker= "o", edgecolor="black")
plt.savefig("../Images/latvswind.png")
plt.show()

print(f"The max windspeeds are primarily clustered below 15mph, with a fairly even distribution of cities across -60 to 80 degrees latitude.")
# Out:
# The max windspeeds are primarily clustered below 15mph, with a fairly even distribution of cities across -60 to 80 degrees latitude.

# %% [markdown]
# ## Linear Regression

# %%
# separate the plots into Northern Hemisphere (greater than or equal to 0 degrees latitude) and Southern Hemisphere (less than 0 degrees latitude)

northern_hemisphere = city_data_df.loc[city_data_df["Lat"]>=0]
southern_hemisphere = city_data_df.loc[city_data_df["Lat"]<0]

#northern_hemisphere
#southern_hemisphere

#northern_hemisphere.dtypes
#southern_hemisphere.dtypes

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = northern_hemisphere["Lat"]
y_values = northern_hemisphere["Max Temp"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regression = x_values * slope + intercept

regress_label = (f"y={round(slope,2)}x + {round(intercept,2)}")

plt.scatter(x_values, y_values)
plt.plot(x_values, regression, "r-")
plt.title("Northern Hemisphere - Max Temp vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Max Temp (F)")
plt.annotate(regress_label, (5,8), fontsize=10, color="red")
plt.annotate(f'Correlation Coefficient: {round(rvalue,2)}', (5,-5), fontsize=10, color='red')

plt.savefig("../Images/north_latvstemp_regression.png")
plt.show()

print(f"The correlation coefficient of -0.88 supports the strong negative relationship shown in the scatterplot between max temp and latitude.")
print(f"As latitude increases in the northern hemisphere, the max temp decreases in a predictable manner across all cities.")
# Out:
# The correlation coefficient of -0.88 supports the strong negative relationship shown in the scatterplot between max temp and latitude.
# As latitude increases in the northern hemisphere, the max temp decreases in a predictable manner across all cities.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = southern_hemisphere["Lat"]
y_values = southern_hemisphere["Max Temp"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regression = x_values * slope + intercept

regress_label = (f"y={round(slope,2)}x + {round(intercept,2)}")

plt.scatter(x_values, y_values)
plt.plot(x_values, regression, "r-")
plt.title("Southern Hemisphere - Max Temp vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Max Temp (F)")
plt.annotate(regress_label, (-20,50), fontsize=10, color="red")
plt.annotate(f'Correlation Coefficient: {round(rvalue,2)}', (-25,45), fontsize=10, color='red')

plt.savefig("../Images/south_latvstemp_regression.png")
plt.show()

print(f"The correlation coefficient of 0.7 supports the strong positive relationship shown in the scatterplot between max temp and latitude.")
print(f"As latitude increases in the southern hemisphere, the max temp increases in a predictable manner across all cities.")
# Out:
# The correlation coefficient of 0.7 supports the strong positive relationship shown in the scatterplot between max temp and latitude.
# As latitude increases in the southern hemisphere, the max temp increases in a predictable manner across all cities.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = northern_hemisphere["Lat"]
y_values = northern_hemisphere["Humidity"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regression = x_values * slope + intercept

regress_label = (f"y={round(slope,2)}x + {round(intercept,2)}")

plt.scatter(x_values, y_values)
plt.plot(x_values, regression, "r-")
plt.title("Northern Hemisphere - Humidity vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Humidity %")
plt.annotate(regress_label, (60, 20), fontsize=10, color="red")
plt.annotate(f'Correlation Coefficient: {round(rvalue,2)}', (45,5), fontsize=10, color='red')

plt.savefig("../Images/north_latvshumidity_regression.png")
plt.show()

print(f"The correlation coefficient of 0.21 reflects a weak positive relationship between humidity % and increasing latitude.")
print(f"That said, the data points reflect a concentrated, yet relatively even distribution of humidity % between 50-100% across the range of latitudes in the northern hemisphere.")
# Out:
# The correlation coefficient of 0.21 reflects a weak positive relationship between humidity % and increasing latitude.
# That said, the data points reflect a concentrated, yet relatively even distribution of humidity % between 50-100% across the range of latitudes in the northern hemisphere.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = southern_hemisphere["Lat"]
y_values = southern_hemisphere["Humidity"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regression = x_values * slope + intercept

regress_label = (f"y={round(slope,2)}x + {round(intercept,2)}")

plt.scatter(x_values, y_values)
plt.plot(x_values, regression, "r-")
plt.title("Southern Hemisphere - Humidity vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Humidity %")
plt.annotate(regress_label, (-15, 40), fontsize=10, color="red")
plt.annotate(f'Correlation Coefficient: {round(rvalue,2)}', (-25, 22), fontsize=10, color='red')

plt.savefig("../Images/south_latvshumidity_regression.png")
plt.show()

print(f"Similar to the north, the correlation coefficient of 0.31 in the southern hemispher reflects a weak positive relationship between humidity % and increasing latitude.")
print(f"The data points reflect the majority of cities having at least 50% humidity, which increases somewhat predictably as you get closer to the equator.")
# Out:
# Similar to the north, the correlation coefficient of 0.31 in the southern hemispher reflects a weak positive relationship between humidity % and increasing latitude.
# The data points reflect the majority of cities having at least 50% humidity, which increases somewhat predictably as you get closer to the equator.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = northern_hemisphere["Lat"]
y_values = northern_hemisphere["Cloudiness"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regression = x_values * slope + intercept

regress_label = (f"y={round(slope,2)}x + {round(intercept,2)}")

plt.scatter(x_values, y_values)
plt.plot(x_values, regression, "r-")
plt.title("Northern Hemisphere - Cloudiness % vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness %")
plt.annotate(regress_label, (38, 60), fontsize=10, color="red")
plt.annotate(f'Correlation Coefficient: {round(rvalue,2)}', (45, 45), fontsize=10, color='red')

plt.savefig("../Images/north_latvsclouds_regression.png")
plt.show()

print(f"The linear regression supports the assumption made above that % cloudiness is almost unpredictable in the northern hemisphere across the range of latitudes.")
# Out:
# The linear regression supports the assumption made above that % cloudiness is almost unpredictable in the northern hemisphere across the range of latitudes.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = southern_hemisphere["Lat"]
y_values = southern_hemisphere["Cloudiness"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regression = x_values * slope + intercept

regress_label = (f"y={round(slope,2)}x + {round(intercept,2)}")

plt.scatter(x_values, y_values)
plt.plot(x_values, regression, "r-")
plt.title("Southern Hemisphere - Cloudiness % vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness %")
plt.annotate(regress_label, (-55, 70), fontsize=10, color="red")
plt.annotate(f'Correlation Coefficient: {round(rvalue,2)}', (-55, 10), fontsize=10, color='red')

plt.savefig("../Images/south_latvsclouds_regression.png")
plt.show()

print(f"In the southern hemisphere there is a weak positive relationship between cloudiness % and latitude.")
print(f"This is reflected in the 0.33 correlation coefficient.")
print(f"Given the weak relationship, further analysis is warranted if this is an important factor.")
# Out:
# In the southern hemisphere there is a weak positive relationship between cloudiness % and latitude.
# This is reflected in the 0.33 correlation coefficient.
# Given the weak relationship, further analysis is warranted if this is an important factor.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = northern_hemisphere["Lat"]
y_values = northern_hemisphere["Wind Speed"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regression = x_values * slope + intercept

regress_label = (f"y={round(slope,2)}x + {round(intercept,2)}")

plt.scatter(x_values, y_values)
plt.plot(x_values, regression, "r-")
plt.title("Northern Hemisphere - Windspeed vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.annotate(regress_label, (0, 30), fontsize=10, color="red")
plt.annotate(f'Correlation Coefficient: {round(rvalue,2)}', (0, 25), fontsize=10, color='red')

plt.savefig("../Images/north_latvswind_regression.png")
plt.show()

print(f"The linear regression reflects almost no correlation between wind speeds and latitude in the northern hemisphere.")
# Out:
# The linear regression reflects almost no correlation between wind speeds and latitude in the northern hemisphere.

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = southern_hemisphere["Lat"]
y_values = southern_hemisphere["Wind Speed"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regression = x_values * slope + intercept

regress_label = (f"y={round(slope,2)}x + {round(intercept,2)}")

plt.scatter(x_values, y_values)
plt.plot(x_values, regression, "r-")
plt.title("Southern Hemisphere - Windspeed vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.annotate(regress_label, (-50, 24), fontsize=10, color="red")
plt.annotate(f'Correlation Coefficient: {round(rvalue,2)}', (-25, 24), fontsize=10, color='red')

plt.savefig("../Images/south_latvswind_regression.png")
plt.show()

print(f"This regression points toward a weak negative relationship between a cities windspeed and its latitude.")
print(f"Wind speed south of the equator is more predictable than north of the equator for this data set.")
# Out:
# This regression points toward a weak negative relationship between a cities windspeed and its latitude.
# Wind speed south of the equator is more predictable than north of the equator for this data set.
